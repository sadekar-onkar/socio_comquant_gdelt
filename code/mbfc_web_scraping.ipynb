# %% [markdown]
# # Media Bias / Fact Check (MBFC)
#
# - https://mediabiasfactcheck.com/

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://mediabiasfactcheck.com/"

categories = ["center", "left", "leftcenter", "right-center", "right"]

# %% [markdown]
# ## Collect URLs from Media Bias / Fact Check (MBFC)

# %%
mbfc_df = pd.DataFrame(columns=["title_full", "url", "category"])

print(f"Categories to be collected: {categories}")

for category in categories:
    url = base_url + category
    print(f"Collecting URLs from: {url}", end=" ... ")
    
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
    
    table = soup.find(name="table", attrs={"id":"mbfc-table"})
    table_rows = table.find_all("td")

    title_to_url = {}

    for row in table_rows:
        title_full = row.text
        try:
            url = row.find("a").get("href")
        except:
            url = ""
        title_to_url[title_full] = url
        
    df_temp = pd.DataFrame(pd.Series(title_to_url)).reset_index().rename({"index":"title_full", 0:"url"}, axis=1)
    df_temp["category"] = category
    
    mbfc_df = pd.concat([mbfc_df, df_temp]).reset_index(drop=True)
    print("Completed!")
print("All the URLs are collected!!!")
# Out:
# Categories to be collected: ['center', 'left', 'leftcenter', 'right-center', 'right']
# Collecting URLs from: https://mediabiasfactcheck.com/center ... Completed!
# Collecting URLs from: https://mediabiasfactcheck.com/left ... Completed!
# Collecting URLs from: https://mediabiasfactcheck.com/leftcenter ... Completed!
# Collecting URLs from: https://mediabiasfactcheck.com/right-center ... Completed!
# Collecting URLs from: https://mediabiasfactcheck.com/right ... Completed!
# All the URLs are collected!!!

# %%
mbfc_df[mbfc_df["url"] == ""]
# Out:
#       title_full url      category
# 0          \n\n             center
# 63          \n\n            center
# 1353  \n\n\n\n\n              left
# 1404        \n\n              left
# 1751        \n\n        leftcenter
# 2833        \n\n      right-center
# 3399        \n\n             right

# %%
# Drop rows with empty URL value
mbfc_df = mbfc_df[mbfc_df["url"] != ""].reset_index(drop=True)

# %%
mbfc_df["title_slug"] = mbfc_df["url"].apply(lambda x: x.split("/")[3])
mbfc_df["title"] = mbfc_df["title_full"].apply(lambda x: x.split("(")[0].strip())

mbfc_df = mbfc_df[["title_full", "title", "title_slug", "url", "category"]]

# %%
mbfc_df.head(3)
# Out:
#                        title_full           title    title_slug  \
# 0        9News – KUSA (9news.com)    9News – KUSA    9news-kusa
# 1  11 News – KKCO (nbc11news.com)  11 News – KKCO  11-news-kkco
# 2       12 News KPNX (12news.com)    12 News KPNX  12-news-kpnx
#
#                                             url category
# 0    https://mediabiasfactcheck.com/9news-kusa/   center
# 1  https://mediabiasfactcheck.com/11-news-kkco/   center
# 2  https://mediabiasfactcheck.com/12-news-kpnx/   center

# %%
mbfc_df.tail(3)
# Out:
#                                          title_full  \
# 3600                 World Magazine (world.wng.org)
# 3601      Yellow Hammer News (yellowhammernews.com)
# 3602  Young Americas Foundation (YAF) (www.yaf.org)
#
#                           title                     title_slug  \
# 3600             World Magazine                 world-magazine
# 3601         Yellow Hammer News              yellowhammer-news
# 3602  Young Americas Foundation  young-americas-foundation-yaf
#
#                                                     url category
# 3600     https://mediabiasfactcheck.com/world-magazine/    right
# 3601  https://mediabiasfactcheck.com/yellowhammer-news/    right
# 3602  https://mediabiasfactcheck.com/young-americas-...    right

# %%
mbfc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3603 entries, 0 to 3602
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title_full  3603 non-null   object
#  1   title       3603 non-null   object
#  2   title_slug  3603 non-null   object
#  3   url         3603 non-null   object
#  4   category    3603 non-null   object
# dtypes: object(5)
# memory usage: 140.9+ KB

# %%
mbfc_df["category"].value_counts()
# Out:
# center          1317
# leftcenter      1077
# right-center     598
# left             365
# right            246
# Name: category, dtype: int64

# %%
mbfc_df.to_csv("data/mbfc_urls.csv", index=False, encoding="utf-8")
mbfc_df.to_excel("data/mbfc_urls.xlsx", index=False, encoding="utf-8")

# %% [markdown]
# ## Collect Bias Info from URLs

# %%
bias_df = pd.DataFrame()

for i, url in enumerate(mbfc_df["url"].values):
    if i % 50 == 0:
        print(f"{i:,}/{mbfc_df.shape[0]:,} | {i/mbfc_df.shape[0]*100:.2f}%")
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text)
        rows = [item for item in soup.find_all("p") if "Bias Rating:" in item.text or "Factual Reporting:" in item.text][-1].text.split("\n")
        bias_temp = pd.DataFrame(pd.Series({"url":url} | {'_'.join(row.split(":")[0].lower().split(" ")): row.split(":")[1].strip() for row in rows})).T
        bias_df = pd.concat([bias_df, bias_temp]).reset_index(drop=True)
    except Exception as e:
        print("-"*60)
        print(f"{i}- {url}")
        print(f"Error:\n{e}")
        print("-"*60)
    
print(f"{mbfc_df.shape[0]:,}/{mbfc_df.shape[0]:,} | {mbfc_df.shape[0]/mbfc_df.shape[0]*100:.2f}%")
print("COMPLETED!!!")
# Out:
# 0/3,603 | 0.00%
# 50/3,603 | 1.39%
# 100/3,603 | 2.78%
# 150/3,603 | 4.16%
# 200/3,603 | 5.55%
# 250/3,603 | 6.94%
# 300/3,603 | 8.33%
# 350/3,603 | 9.71%
# 400/3,603 | 11.10%
# 450/3,603 | 12.49%
# 500/3,603 | 13.88%
# ------------------------------------------------------------
# 544- https://mediabiasfactcheck.com/ktft-twin-falls-news-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 546- https://mediabiasfactcheck.com/ktka-topeka-news-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 547- https://mediabiasfactcheck.com/ktla/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 548- https://mediabiasfactcheck.com/ktmf-missoula-news-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# 550/3,603 | 15.27%
# ------------------------------------------------------------
# 551- https://mediabiasfactcheck.com/ktre-lufkin-news-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# 600/3,603 | 16.65%
# 650/3,603 | 18.04%
# 700/3,603 | 19.43%
# ------------------------------------------------------------
# 730- https://mediabiasfactcheck.com/north-platte-telegraph-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 731- https://mediabiasfactcheck.com/north-port-sun/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 734- https://mediabiasfactcheck.com/northwest-herald-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 736- https://mediabiasfactcheck.com/novinite/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 737- https://mediabiasfactcheck.com/oakland-press-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 738- https://mediabiasfactcheck.com/ogemaw-county-herald-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 739- https://mediabiasfactcheck.com/opelika-auburn-news/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 747- https://mediabiasfactcheck.com/oswego-ledger-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
#
bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 2431- https://mediabiasfactcheck.com/public-citizen/
# Error:
# list index out of range
# ------------------------------------------------------------
# 2,450/3,603 | 68.00%
# 2,500/3,603 | 69.39%
# 2,550/3,603 | 70.77%
# ------------------------------------------------------------
# 2593- https://mediabiasfactcheck.com/the-irrawaddy/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 2596- https://mediabiasfactcheck.com/the-journalists-resource-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# 2,600/3,603 | 72.16%
# 2,650/3,603 | 73.55%
# 2,700/3,603 | 74.94%
# 2,750/3,603 | 76.33%
# 2,800/3,603 | 77.71%
# 2,850/3,603 | 79.10%
# 2,900/3,603 | 80.49%
# 2,950/3,603 | 81.88%
# 3,000/3,603 | 83.26%
# 3,050/3,603 | 84.65%
# 3,100/3,603 | 86.04%
# 3,150/3,603 | 87.43%
# ------------------------------------------------------------
# 3166- https://mediabiasfactcheck.com/red-river-valley-news/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 3167- https://mediabiasfactcheck.com/regina-leader-post/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 3168- https://mediabiasfactcheck.com/regulation-magazine/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 3169- https://mediabiasfactcheck.com/remington-research-group/
# Error:
# list index out of range
# ------------------------------------------------------------
# ------------------------------------------------------------
# 3170- https://mediabiasfactcheck.com/republic-world/
# Error:
# list index out of range
# ------------------------------------------------------------
# 3,200/3,603 | 88.81%
# 3,250/3,603 | 90.20%
# 3,300/3,603 | 91.59%
# 3,350/3,603 | 92.98%
# 3,400/3,603 | 94.37%
# 3,450/3,603 | 95.75%
# ------------------------------------------------------------
# 3459- https://mediabiasfactcheck.com/florida-daily-bias/
# Error:
# list index out of range
# ------------------------------------------------------------
# 3,500/3,603 | 97.14%
# 3,550/3,603 | 98.53%
# ------------------------------------------------------------
# 3594- https://mediabiasfactcheck.com/washington-examiner/
# Error:
# list index out of range
# ------------------------------------------------------------
# 3,600/3,603 | 99.92%
# 3,603/3,603 | 100.00%
# COMPLETED!!!

# %%
bias_df.head(3)
# Out:
#                                             url   bias_rating  \
# 0    https://mediabiasfactcheck.com/9news-kusa/  LEAST BIASED
# 1  https://mediabiasfactcheck.com/11-news-kkco/  LEAST BIASED
# 2  https://mediabiasfactcheck.com/12-news-kpnx/  LEAST BIASED
#
#   factual_reporting country press_freedom_rating  media_type  \
# 0              HIGH     USA          MOSTLY FREE  TV Station
# 1              HIGH     USA          MOSTLY FREE  TV Station
# 2              HIGH     USA          MOSTLY FREE  TV Station
#
#   traffic/popularity mbfc_credibility_rating mbfc’s_country_freedom_rating  \
# 0       High Traffic        HIGH CREDIBILITY                           NaN
# 1     Medium Traffic        HIGH CREDIBILITY                           NaN
# 2     Medium Traffic        HIGH CREDIBILITY                           NaN
#
#   mbfc’s_freedom_rating press_freedom_rank world_press_freedom_rank  \
# 0                   NaN                NaN                      NaN
# 1                   NaN                NaN                      NaN
# 2                   NaN                NaN                      NaN
#
#   mbfc’s_country_freedom_rank mbfc’s_country_freedom_profile  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
#
#   press_freedom_rating_ mbfc_country_freedom_rating reasoning  \
# 0                   NaN                         NaN       NaN
# 1                   NaN                         NaN       NaN
# 2                   NaN                         NaN       NaN
#
#   _world_press_freedom_rank questionable_reasoning
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN

# %%
bias_df.tail(3)
# Out:
#                                                     url bias_rating  \
# 3550     https://mediabiasfactcheck.com/world-magazine/       RIGHT
# 3551  https://mediabiasfactcheck.com/yellowhammer-news/       RIGHT
# 3552  https://mediabiasfactcheck.com/young-americas-...       RIGHT
#
#      factual_reporting country press_freedom_rating               media_type  \
# 3550             MIXED     USA                  NaN                 Magazine
# 3551              HIGH     USA          MOSTLY FREE                  Website
# 3552             MIXED     USA                  NaN  Organization/Foundation
#
#      traffic/popularity mbfc_credibility_rating mbfc’s_country_freedom_rating  \
# 3550     Medium Traffic      MEDIUM CREDIBILITY                           NaN
# 3551    Minimal Traffic        HIGH CREDIBILITY                           NaN
# 3552       High Traffic      MEDIUM CREDIBILITY                           NaN
#
#      mbfc’s_freedom_rating press_freedom_rank world_press_freedom_rank  \
# 3550                   NaN        MOSTLY FREE                      NaN
# 3551                   NaN                NaN                      NaN
# 3552                   NaN        MOSTLY FREE                      NaN
#
#      mbfc’s_country_freedom_rank mbfc’s_country_freedom_profile  \
# 3550                         NaN                            NaN
# 3551                         NaN                            NaN
# 3552                         NaN                            NaN
#
#      press_freedom_rating_ mbfc_country_freedom_rating reasoning  \
# 3550                   NaN                         NaN       NaN
# 3551                   NaN                         NaN       NaN
# 3552                   NaN                         NaN       NaN
#
#      _world_press_freedom_rank questionable_reasoning
# 3550                       NaN                    NaN
# 3551                       NaN                    NaN
# 3552                       NaN                    NaN

# %%
bias_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3553 entries, 0 to 3552
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   url                             3553 non-null   object
#  1   bias_rating                     3428 non-null   object
#  2   factual_reporting               3553 non-null   object
#  3   country                         3546 non-null   object
#  4   press_freedom_rating            2042 non-null   object
#  5   media_type                      3428 non-null   object
#  6   traffic/popularity              3428 non-null   object
#  7   mbfc_credibility_rating         3428 non-null   object
#  8   mbfc’s_country_freedom_rating   469 non-null    object
#  9   mbfc’s_freedom_rating           9 non-null      object
#  10  press_freedom_rank              756 non-null    object
#  11  world_press_freedom_rank        119 non-null    object
#  12  mbfc’s_country_freedom_rank     69 non-null     object
#  13  mbfc’s_country_freedom_profile  1 non-null      object
#  14  press_freedom_rating_           1 non-null      object
#  15  mbfc_country_freedom_rating     7 non-null      object
#  16  reasoning                       1 non-null      object
#  17  _world_press_freedom_rank       1 non-null      object
#  18  questionable_reasoning          2 non-null      object
# dtypes: object(19)
# memory usage: 527.5+ KB

# %%
bias_df.isna().sum()
# Out:
# url                                  0
# bias_rating                        125
# factual_reporting                    0
# country                              7
# press_freedom_rating              1511
# media_type                         125
# traffic/popularity                 125
# mbfc_credibility_rating            125
# mbfc’s_country_freedom_rating     3084
# mbfc’s_freedom_rating             3544
# press_freedom_rank                2797
# world_press_freedom_rank          3434
# mbfc’s_country_freedom_rank       3484
# mbfc’s_country_freedom_profile    3552
# press_freedom_rating_             3552
# mbfc_country_freedom_rating       3546
# reasoning                         3552
# _world_press_freedom_rank         3552
# questionable_reasoning            3551
# dtype: int64

# %%
bias_df.to_csv("data/bias_data.csv", index=False, encoding="utf-8")
bias_df.to_excel("data/bias_data.xlsx", index=False, encoding="utf-8")
